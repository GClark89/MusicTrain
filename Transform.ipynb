# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

#Brining back the original csv to clean and prepal for the model
file_path = r"/Users/sa8/Desktop/MusicTrain/data/train.csv"

df = pd.read_csv(file_path)

# %%
#Dropped columns with objects in them and dropped the unnamed column as well as it doesn't seem useful 
df = df.drop(columns=["lyrics","artist_name","track_name","topic","genre","Unnamed: 0" , "release_date"], axis= 1)

# %%
# Lets scale the len column to perfect match the other columns in our dataset to prepare for k-means clustering
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit and transform the 'Len' column 
df['len_scaled'] = scaler.fit_transform(df[['len']])

df['len_scaled'].to_frame()
# Out:
#        len_scaled
# 0        0.474747
# 1        0.252525
# 2        0.116162
# 3        0.267677
# 4        0.237374
# ...           ...
# 28357    0.388889
# 28358    0.333333
# 28359    0.383838
# 28360    0.333333
# 28361    0.414141
#
# [28362 rows x 1 columns]

# %%
#Now since we have len scaled we can drop the original len column 
df = df.drop(columns=['len'])

# %%
df.isnull().sum()
# Out:
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# sadness                     0
# feelings                    0
# age                         0
# len_scaled                  0
# dtype: int64

# %%
df.head()
# Out:
#      dating  violence  world/life  night/time  shake the audience  \
# 0  0.000598  0.063746    0.000598    0.000598            0.000598
# 1  0.035537  0.096777    0.443435    0.001284            0.001284
# 2  0.002770  0.002770    0.002770    0.002770            0.002770
# 3  0.048249  0.001548    0.001548    0.001548            0.021500
# 4  0.001350  0.001350    0.417772    0.001350            0.001350
#
#    family/gospel  romantic  communication   obscene     music  \
# 0       0.048857  0.017104       0.263751  0.000598  0.039288
# 1       0.027007  0.001284       0.001284  0.001284  0.118034
# 2       0.002770  0.158564       0.250668  0.002770  0.323794
# 3       0.001548  0.411536       0.001548  0.001548  0.001548
# 4       0.001350  0.463430       0.001350  0.001350  0.001350
#
#    movement/places  light/visual perceptions  family/spiritual   sadness  \
# 0         0.000598                  0.000598          0.000598  0.380299
# ...

# %%
df.describe()
# Out:
#              dating      violence    world/life    night/time  \
# count  28362.000000  28362.000000  28362.000000  28362.000000
# mean       0.021110      0.118371      0.120984      0.057356
# std        0.052366      0.178658      0.172216      0.111892
# min        0.000291      0.000284      0.000291      0.000289
# 25%        0.000923      0.001120      0.001170      0.001032
# 50%        0.001462      0.002506      0.006579      0.001949
# 75%        0.004049      0.192538      0.197854      0.065778
# max        0.647706      0.981781      0.962105      0.973684
#
#        shake the audience  family/gospel      romantic  communication  \
# count        28362.000000   28362.000000  28362.000000   28362.000000
# mean             0.017418       0.017045      0.048676       0.076651
# std              0.040658       0.041968      0.106071       0.109497
# min              0.000284       0.000289      0.000284       0.000291
# ...

# %%
#Save Cleaned data to csv 
df.to_csv("data/CleanedMusic.csv")
